# %%
# !pip install yfinance

# %%
import pandas as pd
import yfinance as yf

url = 'https://id.wikipedia.org/wiki/Daftar_perusahaan_yang_tercatat_di_Bursa_Efek_Indonesia'
html = pd.read_html(url, header=0)
df_1 = html[0]
df_2 = html[1]
df_3 = html[2]
df_4 = html[3]
df_5 = html[4]
df_6 = html[5]
df_7 = html[6]
df_8 = html[7]
df_9 = html[8]

df_1['Industri'] = 'General'
df_2['Industri'] = 'Pertanian'
df_3['Industri'] = 'Barang Konsumen'
df_4['Industri'] = 'Lainnya'
df_5['Industri'] = 'Keuangan'
df_6['Industri'] = 'Perdagangan, Layanan, dan Investasi'
df_7['Industri'] = 'Kontruksi Properti, Real Estate, dan Bangunan'
df_8['Industri'] = 'Bahan Kimia'
df_9['Industri'] = 'Pertambagan'

df_1.rename(columns={'Tanggal pencatatan':'Tanggal Listing'}, inplace=True)
df_2.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
df_3.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
df_4.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
df_5.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
df_6.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
df_7.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
df_8.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
df_9.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)

pdLists = [df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9]
rawDataFrame = pd.concat(pdLists)

rawDataFrame[['Bursa','Kode Saham']] = rawDataFrame['Kode'].copy().str.split(':', expand=True)
rawDataFrame['Bursa'].str.strip()
rawDataFrame['Kode Saham'].str.strip()

rawDataFrame.drop(columns=['Kode'], axis=1, inplace=True)
rawDataFrame.sort_values(by='Kode Saham', ascending=True, inplace=True)

rawDataFrame['Kode Yahoo Finance'] = rawDataFrame['Kode Saham'].astype(str) + '.JK'

rawDataFrame.reset_index(drop=True, inplace=True)

# %%
import pandas as pd
import yfinance as yf

# %%
def load_data():
  url = 'https://id.wikipedia.org/wiki/Daftar_perusahaan_yang_tercatat_di_Bursa_Efek_Indonesia'
  html = pd.read_html(url, header=0)
  df_1 = html[0]
  df_2 = html[1]
  df_3 = html[2]
  df_4 = html[3]
  df_5 = html[4]
  df_6 = html[5]
  df_7 = html[6]
  df_8 = html[7]
  df_9 = html[8]

  df_1['Industri'] = 'General'
  df_2['Industri'] = 'Pertanian'
  df_3['Industri'] = 'Barang Konsumen'
  df_4['Industri'] = 'Lainnya'
  df_5['Industri'] = 'Keuangan'
  df_6['Industri'] = 'Perdagangan, Layanan, dan Investasi'
  df_7['Industri'] = 'Kontruksi Properti, Real Estate, dan Bangunan'
  df_8['Industri'] = 'Bahan Kimia'
  df_9['Industri'] = 'Pertambagan'

  df_1.rename(columns={'Tanggal pencatatan':'Tanggal Listing'}, inplace=True)
  df_2.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
  df_3.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
  df_4.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
  df_5.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
  df_6.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
  df_7.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
  df_8.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)
  df_9.rename(columns={'Tanggal pencatatatan':'Tanggal Listing'}, inplace=True)

  pdLists = [df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9]
  rawDataFrame = pd.concat(pdLists)

  rawDataFrame[['Bursa','Kode Saham']] = rawDataFrame['Kode'].copy().str.split(':', expand=True)
  rawDataFrame['Bursa'].str.strip()
  rawDataFrame['Kode Saham'].str.strip()

  rawDataFrame.drop(columns=['Kode'], axis=1, inplace=True)
  rawDataFrame.sort_values(by='Kode Saham', ascending=True, inplace=True)

  rawDataFrame['Kode Yahoo Finance'] = rawDataFrame['Kode Saham'].astype(str) + '.JK'

  rawDataFrame.reset_index(drop=True, inplace=True)
  return rawDataFrame

# %%
dfr = load_data()
display(dfr.head(10))
# Out:
#                      Nama perusahaan  ... Kode Yahoo Finance
# 0             Astra Agro Lestari Tbk  ...            AALI.JK
# 1                   Mahaka Media Tbk  ...            ABBA.JK
# 2        Asuransi Bina Dana Arta Tbk  ...            ABDA.JK
# 3                  ABM Investama Tbk  ...            ABMM.JK
# 4         Ace Hardware Indonesia Tbk  ...            ACES.JK
# 5             PT Acset Indonusa Tbk.  ...            ACST.JK
# 6  Akasha Wira International Tbk Tbk  ...            ADES.JK
# 7    PT Adindo Foresta Indonesia Tbk  ...            ADFO.JK
# 8       PT Adhi Karya (Persero) Tbk.  ...            ADHI.JK
# 9   Adira Dinamika Multi Finance Tbk  ...            ADMF.JK
#
# [10 rows x 6 columns]
